# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
img = cv2.imread('1.jpg')

# %%
H, W, _ = img.shape

horizon_height = 0.848 * H
down_width = 15

b_l = [ 0, H ]
b_r = [ W, H ]

u = 100
tetha = np.pi/2 - np.arctan((2*horizon_height)/W)
x = np.tan(tetha) * u
t_l = [ W/2-x, H-horizon_height+u ]
t_r = [ W/2+x, H-horizon_height+u ]


figure_map = plt.figure(figsize=(10,10))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.plot(kp[:,0], kp[:,1], '.r')
plt.plot([0, W], [H-horizon_height, H-horizon_height], 'g')

# %%
kp = np.array([t_l,t_r, b_l, b_r])

map_h, map_w = 255, 255
map_points = np.array([[0,0],[0,map_w],[map_h,map_w], [map_h, 0]])

H, _ = cv2.findHomography(map_points, kp, cv2.RANSAC, 100.0)

# %%
# Out:
# array([[-4.68797823e+00,  6.19093712e-01,  1.03756555e+03],
#        [-1.84886459e+00,  0.00000000e+00,  3.53536011e+02],
#        [-4.19881615e-03,  0.00000000e+00,  1.00000000e+00]])
